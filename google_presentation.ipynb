# %% [markdown]
# # Understanding my covid lockdown phone calls
# When Covid-19 hit us earlier this year, life changed around the world for many people all at the same time. Usually large natural disasters or distablising events affect one country or part of the world (e.g. bushfires in Australia, terrorist attacks in France), or hit one segment of the global community (e.g. the Global Financial Crisis of 2007-08), not everybody in very similar ways. With an international family, it is interesting to hear local perspectives about those events. Covid was different, it affected everyone, largely at once (particularly the areas where my family are, case numbers started to increase and lockdowns commenced around the same time), and the local perspectives became even more fascinating, to understand how different governments and local populations were responding.
#
# This small project arose in light of those conversations. I wanted to understand how the different policies in different countries, regions were actually responding compared to the stories I was hearing from my family around the world.
#
# ### Research question
# - How did people's movement change as a result of covid case numbers and government policies in areas where my family are located?
# - Did these changes reflect what I was hearing in my phone conversations?
#
# ### Analysis
# The big two regions of my family are Australia and France, however, I am based in Seattle, so obviously that was of interest to me as well. I also have extended family in Germany, Japan, Brazil. My connections to Brazil and Japan are a quite removed, but I included them because they are two countries that had very different experiences of the coronavirus.
#
# The analysis includes plots of covid case numbers and deaths per 100,000 residents in each country, followed by plots of the google movement data for each of the designated location types (Retail and Recreation, Parks, Groceries, Workplaces, Transit stations, residential). I have also included a short description of government policy requirements mainly at the country level to provide context to the data.
#
# Overtime, Google provided data at increasing granualarity, so in most instances I am able to go the local government area for all locations. My locations include:
# - Australia - Sydney, Melbourne, Townsville
# - King country, Washington State, United States
# - France - Loiret, Indre et Loire, and Bouches du Rhone (movement figures included at the end)
# - Germany - North Rhine-West Philia
# - Japan - Tokyo
# - Brazil - Sao Paulo
#
# ## Conclusions
# The data really does reflect my phone calls to these areas, France and Australia were strict in their lockdown but both with the expectation that return to a reasaonably normal life is possible. Seattle has just had to adjust to the new normal, which means not spending time inside with people outside your covid bubble. Japan has amazing case statistics based on their population size and no broad economic lockdown. Researching media across all countries, what is interesting to see is how similar the debates are despite differences in case numbers. There is always a local nuance, but the debate between the economy and health outcomes can seem just as fierce.
#
# For each country:
# - France you can see big drops due to both lockdowns, reflecting the strictness of the lockdowns.
# - Seattle's first lockdown story was 'don't take our parks away from us'. France's lockdown would never have worked here.
# - All locations have not returned to baseline except Townsville, which has had very very few cases of covid and no local transmission. There has been a step change in working from home for those that could. Will this continue post covid?
# - Sao Paulo has just seen continuous increase in movement since initial lockdown in March, despite case numbers.
#
# My plotting skills have improved considerably as has my ability to use loops. I have tried a few tricks to simplify this runbook for you, and separating out data cleaning from the plots and analysis. Although I think people around me are sick of hearing about covid, maybe like you are, the project was fun and relevant to my life, and I have referred to statistics I have gathered here in numerous conversations.

# %% [markdown]
# ### Sources of data:
# - [Google Movement data](https://www.google.com/covid19/mobility/). The baseline day is the median value from the 5-week period Jan 3 – Feb 6, 2020. One big caveat of the data is that it cannot be used to compare places across regions. As Google says 'Regions can have local differences in the data which might mislead.' This is annoying, as it limits how I can use the data to compare across my family, but the analysis still is interesting.
# - [World population data](https://www.worldometers.info/world-population/population-by-country/)
# - [US covid data](https://covid.cdc.gov/covid-data-tracker/#trends_dailytrendscases)
# - [Our World in Data source](https://github.com/owid/covid-19-data/tree/master/public/data)
#
# Other media sources are noted within the text below.
#
# All data is plotted below using 7 day rolling average mean.
#
# ### Limitations
#
# There are many limitations with the analysis. The data will be biased towards the type of people who have google phones and turn on the location history. I have also only accessed covid case and death data at the national level (except for the US) limiting regional comparisons. I have done limited supporting research, but it has not been extensive. The additional research has also been limited to english new sites.
#
# ### Disclaimer
# Analysis last updated 18 December 2020, and as always covid situation in all countries can change quickly, so some of my analysis may be out of date. Data was last updated 26 December.

# %%
# %run ~/Jupyter/movement_global/google_covid_plot_functions.ipynb

# %%
# %run ~/Jupyter/movement_global/google_data_cleaning.ipynb

# %%
# %run ~/Jupyter/movement_global/covid_data_cleaning.ipynb

# %% [markdown]
# # Covid-19 numbers by country
#
# What is interesting here is that I can group my countries of interest into two categories based on their covid case and death numbers. France, Washington State (US), Germany and Brazil have higher rates of cases and deaths. They are included all on one figure below. Comparatively, Japan and Australia, when looking at per capita rates of cases and deaths are similar, and have much lower numbers per capita than the other four countries.
#
# France's case rates per capita and deaths get to much higher levels than all other countries, but they peak and drop quickly. With the Washington State case rate trending to be higher than the peak of France's, hopefully not.

# %% [markdown]
# ## Countries with higher rates of covid cases and deaths

# %%
covid_cases(covid_country_high, covid_country_names_high, colors_high)

# %%
covid_deaths(covid_country_high, covid_country_names_high, colors_high)

# %% [markdown]
# ## Countries with lower rates of covid cases and deaths

# %%
covid_cases(covid_country_low, covid_country_names_low, colors_low)

# %%
covid_deaths(covid_country_low, covid_country_names_low, colors_low)

# %% [markdown]
# # Regional movement data

# %% [markdown]
# # Australia

# %% [markdown]
# Australia went into lockdown around the same time as the rest of the world, but with much lower case numbers than many parts of the world. With borders shut on the island nation and with the country in lockdown, they were able to get case numbers under control quickly and to very low numbers. After bumps along the road for Melbourne, Australia is about to have a very normal Christmas unlike much of the rest of the world.
#
#
# Interesting insight about Australia, they closed borders everywhere they could. State borders, international borders, and this has helped contain outbreaks in certain areas of the country and out of the country. But their treatment of Australian citizens wanting to get home has been appalling.

# %%
plot_my_grouped_plot_covid(covid_australia)

# %% [markdown]
# ## Australian
# Locking down: Australia first locked its borders to the outside world (non-Australians and permanent residents banned from China February 1, and from all international destinations March 18) before locking down its citizens (late March). Many state borders were closed in March, and many have stayed in place until November and December.
#
# Opening up: Nationwide lockdown restrictions were ease May 8.
#
# Second wave: A resurgence in case numbers was experience in Melbourne, and a renewed lockdown was put in place in Melbourne July 9 and then further tightened August 2. This lockdown was much stricter than for the first wave, with case numbers much higher.
#
# Opening up again in Melbourne: Restrictions were eased at the end of September and the stay-at-home order was lifted at the end of October.

# %%
plot_my_grouped_plot(australia)

# %% [markdown]
# ## Regional differences
#
# Due to the large second wave in Melbourne, there are quite large regional differences in Australia's data but also differences between my regions of interest, Sydney, Melbourne and Townsville. Melbourne had a large second wave. Sydney had cases continue over the winter in quite small numbers, mainly through outbreaks at certain places. Townsville seemed to be sheltered from covid, with only ever having covid cases that were acquired elsewhere. All these differences can be seen, in their movement data.

# %% [markdown]
# ### Sydney

# %% [markdown]
# What is interesting in the Sydney data is that despite very low cases numbers since May/June, people have continued to work from home and not take public transport.

# %%
plot_my_grouped_plot(total_sydney)

# %% [markdown]
# ### Melbourne

# %% [markdown]
# The strigency of Melbourne's second lockdown can be seen in the drop in attendance at parks in September, with people only allowed to leave their house for one hour per day and only within 5 kilometre radius.

# %%
plot_my_grouped_plot(total_melbourne)

# %% [markdown]
# ### Townsville

# %% [markdown]
# Townsville was very protected from the spread of the virus and that can be seen in its movement numbers, with movement pretty much returning back to normal by September.

# %%
plot_my_grouped_plot(townsville)

# %% [markdown]
# # Washington State, United States

# %% [markdown]
# Focusing on Seattle only, not the United States (too many different stories across the US for me to cover here). Seattle was the first place in the US to have a known covid case. Covid also quickly entered aged care facilities, which led to a high death rate at the beginning of the outbreak. This lead to an earlier response to the pandemic than much of the rest of the United States, lead by many big employers, after all Microsoft is here, and at the time, Bill Gates was still on their board.
#
# To get it out of the way, mask wearing in Seattle was taken up fairly rapidly both in government policy and across the community. The interesting story here has been 'Don't take our parks away'. I heard it on the radio, among friends and you can see it in the data. Seattlites love their parks and they would not have stood for them being taken away from them (although parking was closed for most of the summer trying to limit park use). This was helped by the fact that we were going into summer, so you can understand it, but the call of 'potential outrage' was large. Washington State is different from the rest of the country, but freedom still matters here.

# %% [markdown]
# ## Covid numbers

# %%
plot_my_grouped_plot_covid(cases_wa)

# %% [markdown]
# ## King County - movement

# %% [markdown]
# Locking down: State of emergency was announced February 29. March 2 many large businesses started sending their employees to work from home and some schools started to close (many of which have not reopened since). Then between March 11 and 16, various businesses were directed to close, with a stay-at-home order announced on March 23. April 5 face masks were recommended. It was recommended that only take essential travel up until July, but people were flying and travelling around the country pretty easily.
#
# Opening up: Officially the stay-at-home order was lifted June 1, but as it was never really enforced, many people stayed at home for a few weeks and then started to leave more and more, visiting parks mainly. Many restrictions stayed until early July when outdoor recreation with groups of five or less was permitted, and hair salons and restaurants, among other things, re-opened. But things never really went anywhere near normal.
#
# Second wave: Case numbers started to increase in October and then accelerate in November. New restrictions were announced on November 15, focusing on restricting indoor gatherings (now exceptions are allowed if individuals quarantine for 7 days and have a negative covid test).  There are now quarantine requirements for those travelling into Washington State from another state or from another country.

# %%
plot_my_grouped_plot(seattle)

# %% [markdown]
# ## France

# %% [markdown]
# Out of all my conversations, France seemed to have the most strict and enforced lockdown in March, and this can be seen again in the data, with very large and steep drops in out of home activities in March. France however, had a glorious summer, with many restrictions lifted people travelled everywhere, again demonstrated in my conversations and the data. They are back in lockdown again, but it is not quite as severe this time. You can see in the steep lockdown drop in the data again.

# %% [markdown]
# ## Covid numbers

# %%
plot_my_grouped_plot_covid(covid_france)

# %% [markdown]
# ## France - movement

# %% [markdown]
# Locking down: France closed down schools, non essential activities, outings and long distance travel in mid March. During the lockdown, citizens were allowed to leave the house for 1 hour per day for exercising, or grocery shopping, and were required to register online, print and carry a note outlining the purpose for leaving the house.
#
# Opening up: Restrictions started to ease May 11, with most major domestic and internal and intra-European travel restrictions lifted June 22.
#
# Second wave: The second wave first hit major metropoles in France, with then night curfews imposed in those centres at the end of August. October 30 a partial lockdown was reinstated, but schools have remained open. This lockdown has allowed a larger range of businesses to remain open, but requirements to register and carry form for reason to leave is again being used. Intra European borders remain open, but extra-European borders are closed and travel between french regions is prohibited.
#
# ## Regional differences
# In my french regions of interest, Loiret, Indre et Loire, and Bouches du Rhone, there are not large regional differences compared to that of France. Noting that my regions of interest do not include any of the major cities of France that were shut down earlier than the rest of France in the second wave and were not the part of the country that was hit hardest in the first wave. The regional data for each of the my regions of interest is included at the end of the notebook.

# %%
plot_my_grouped_plot(france)

# %% [markdown]
# # Germany

# %% [markdown]
# I don't have any direct conversations with people in Germany, but it is an interesting case study particularly with second autumn wave. It has been praised for its initial management of the virus, which included widespread testing, some lockdowns and good contact tracing, all resulting in a very low deathtoll, particularly when compared to its European neighbours. But the second wave, while still much lower than its neigbours it is not getting under control, [I have read](https://www.cnbc.com/2020/10/22/germanys-coronavirus-strategy-why-it-might-not-work.html) that this may be due to its regional governance structure, which was beneficial at the beginning but finding concensus is becoming more difficult and that is making it harder for their to be a consistent message delivered to its citizens.
#
# Faced with increasing or at best plateauing case numbers, as can be seen in first plot below), [signs](https://www.dw.com/en/germanys-angela-merkel-calls-for-tougher-coronavirus-restrictions/a-55878244) from Germany indicate that their partial winter lockdown will remain longer than in France.

# %% [markdown]
# ## Covid numbers

# %%
plot_my_grouped_plot_covid(covid_germany)

# %% [markdown]
# ## Movement policy responses
#
# Locking down: Germany closed schools, childcare and postponed academic semseters on March 13 and closed borders with five surrounding countries March 15. It announced the lockdown and national curfew on March 22.
#
# Opening up: Germany began to reopening its economy on April 20, with schools gradually reopening from May 4. May 18 restrictions on other European travellers were lifted.
#
# Second-wave: Late November, a partial lockdown has been announced, with restaurants, bars, leisure facilities to be closed, but schools remain open. Non essential travel is strictly discouraged and hotels must not offer accomodation to tourists.

# %% [markdown]
# ## North Rhine-Westphalia - movement

# %%
plot_my_grouped_plot(rhine)

# %% [markdown]
# # Japan

# %% [markdown]
# ## Covid numbers

# %%
plot_my_grouped_plot_covid(covid_japan)

# %% [markdown]
# ## Tokyo - Movement

# %% [markdown]
# Locking down: Understanding locking down in Japan is difficult, because the national government was not empowered to enforce a lockdown. Instead, Japan's initial response was not to lockdown but instead to advocate to citizens to avoid the three C's: closed spaces, crowded places and close contact settin, and focus on contact tracing on finding superspreader events. However, while no formal lockdown was called by any government, governments, particularly regional governments, called on businesses to close and voluntary stay-at-home orders were in place.
#
# Second wave: Case numbers are currently increasing in Japan and businesses have been requested to close in regions most affected, of which Tokyo is one. Only time will tell about the effectiveness of their policy in face of a stronger second wave in winter.

# %%
plot_my_grouped_plot(tokyo)

# %% [markdown]
# # Brazil

# %% [markdown]
# Brazil's covid case numbers may drastically underestimate the number of cases in the country. A [recent study](https://www.forbes.com/sites/williamhaseltine/2020/10/27/in-brazil-new-study-shows-the-poor-and-indigenous-suffer-the-most-from-covid-19/?sh=1716248535b7) across 140 cities in Brazil, found that only 1 in 10 people with covid antibodies had received a positive test. So it is difficult to draw any conclusions from Brazil's data. Their movement data, though does seem to show people just getting sick of adjusting their life and slowly increasing their movement. Although noting here, that maybe more than other countries, the google data may have its limitations due to potential selection bias as to those who have google phones and have chosen to turn on Location History.
#
# Overall in Brazil, the response to covid seems to have reflected that of the United States, complete denial of the problems at a federal level, some states filling the void but finding it hard to cut throw with disinformation coming from the federal level. Here though, local level initiatives and the response from the community has in some places been stellar, with private hospitals coordinating with smaller hospitals near to poorer communities, and felva presidents stepping up to manage the lockdown logistics in their local areas ([source](https://www.cnbc.com/2020/07/22/brazil-politics-mixed-messages-hurt-response.html)).

# %% [markdown]
# ## Covid numbers

# %%
plot_my_grouped_plot_covid(covid_brazil)

# %% [markdown]
# ## São Paulo - movement

# %% [markdown]
# Locking down: Like most of the rest of the countries, Sao Paulo went into lockdown in late March, with essential businesses able to remain open.
#
# Opening up: There was a gradual reopening of the city, with the City's malls being able to reopen in June with much reduced operating hours ([source](https://www.france24.com/en/20200611-sao-paulo-re-opens-after-lockdown-despite-brazil-s-surging-covid-19-death-toll)). However, many restrictions remained in place or were tightened in June as case numbers spiked. It is difficult to get an exact timeline. Looking at the data below, it seems as though some tightening of restrictions were put in place at the end of August. This affected use of parks, and grocery and pharmacy visits but had minimal effect on other categories of places.
#
# Second wave: Sao Paulo is now again locking down again, as the city has seen a spike in cases towards the end of November. This lockdown will see opening hours and capacities for bars, restaurants and shopping malls restricted ([source](https://wsau.com/2020/11/30/sao-paulo-imposes-covid-19-restrictions-as-cases-surge-again/ )).

# %%
plot_my_grouped_plot(sp)

# %% [markdown]
# # Regional data for France

# %% [markdown]
# ## Loiret

# %%
plot_my_grouped_plot(loire)

# %% [markdown]
# ## Indre et Loire

# %%
plot_my_grouped_plot(indre)

# %% [markdown]
# ## Bouches du Rhone

# %%
plot_my_grouped_plot(bouches)
